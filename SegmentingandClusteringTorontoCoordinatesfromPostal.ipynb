# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M5A  Downtown Toronto
# 4          M6A        North York
# 5          M6A        North York
# 6          M7A      Queen's Park
# 7          M9A         Etobicoke
# 8          M1B       Scarborough
# 9          M1B       Scarborough
# 10         M3B        North York
# 11         M4B         East York
# 12         M4B         East York
# 13         M5B  Downtown Toronto
# 14         M5B  Downtown Toronto
# 15         M6B        North York
# 16         M9B         Etobicoke
# 17         M9B         Etobicoke
# 18         M9B         Etobicoke
# 19         M9B         Etobicoke
# 20         M9B         Etobicoke
# 21         M1C       Scarborough
# 22         M1C       Scarborough
# 23         M1C       Scarborough
# 24         M3C        North York
# 25         M3C        North York
# 26         M4C         East York
# ...

# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#    PostalCode       Borough  NeighborHood
# 85        M7A  Queen's Park  Not assigned

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#    PostalCode       Borough  NeighborHood
# 85        M7A  Queen's Park  Queen's Park

# %%
# The cleand up and merged pandas dataframe
merged_df
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# ...

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# (103, 3)

# %%
# Install the relevant libraries for geocoding
#from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
# !conda install -c conda-forge geocoder --yes
import geocoder
# Out:
# Solving environment: done
#
# # All requested packages already installed.

# %%
###########################################################################################
# This code is not used as it does not return the coordinates, using the CSV file instead #
###########################################################################################
# get the coordinates from the merged_df
coordinate_df = merged_df

def get_geocoder(postal_code_from_coordinate_df):
    # initialize your variable to None
    lat_lng_coords = None
    # loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.google('{}, Toronto, Ontario'.format(postal_code_from_coordinate_df))
        lat_lng_coords = g.latlng
    latitude = lat_lng_coords[0]
    longitude = lat_lng_coords[1]
    return latitude,longitude

for i in range(0,len(coordinate_df)):
    coordinate_df['Latitude'][i],coordinate_df['Longitude'][i]=get_geocoder(coordinate_df.iloc[i]['PostalCode'])


coordinate_df

# %%
# Obtaining the coordinates is problematic, using the CSV file instead, it is ontop for proof of use reasons.

# Read the corordinates online file by the URL provided, and assign it to variable "csv_coordinates_df"
coordinates_path = "http://cocl.us/Geospatial_data/Geospatial_Coordinates.csv"
csv_coordinates_df = pd.read_csv(coordinates_path)
csv_coordinates_df.columns = csv_coordinates_df.columns.str.strip().str.lower().str.replace(' ', '').str.replace('(', '').str.replace(')', '')
csv_coordinates_df
# Out:
#     postalcode   latitude  longitude
# 0          M1B  43.806686 -79.194353
# 1          M1C  43.784535 -79.160497
# 2          M1E  43.763573 -79.188711
# 3          M1G  43.770992 -79.216917
# 4          M1H  43.773136 -79.239476
# 5          M1J  43.744734 -79.239476
# 6          M1K  43.727929 -79.262029
# 7          M1L  43.711112 -79.284577
# 8          M1M  43.716316 -79.239476
# 9          M1N  43.692657 -79.264848
# 10         M1P  43.757410 -79.273304
# 11         M1R  43.750072 -79.295849
# 12         M1S  43.794200 -79.262029
# 13         M1T  43.781638 -79.304302
# 14         M1V  43.815252 -79.284577
# 15         M1W  43.799525 -79.318389
# 16         M1X  43.836125 -79.205636
# 17         M2H  43.803762 -79.363452
# 18         M2J  43.778517 -79.346556
# 19         M2K  43.786947 -79.385975
# 20         M2L  43.757490 -79.374714
# 21         M2M  43.789053 -79.408493
# 22         M2N  43.770120 -79.408493
# 23         M2P  43.752758 -79.400049
# ...

# %%
# Loop through the coordinate dataframe and add the latitude and longitude to the merged_df
coordinate_df = merged_df

# Create empty columns for the latitude and longitude 
coordinate_df['Latitude'] = ""
coordinate_df['Longitude'] = ""

# This can be refactored in the future
for i in range(0,len(coordinate_df)):
    for i in range(0,len(csv_coordinates_df)):
        if (coordinate_df['PostalCode'][i] == csv_coordinates_df['postalcode'][i]):
            coordinate_df['Latitude'][i] = csv_coordinates_df['latitude'][i]
            coordinate_df['Longitude'][i] = csv_coordinates_df['longitude'][i]
            continue # break out of the inner for loop
            
coordinate_df
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# ...
